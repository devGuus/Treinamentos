# %%
import pandas as pd
import matplotlib as plot

df = pd.read_csv('pizzas.csv')
df
# Out:
#     Diametro  Preco
# 0         20     50
# 1         22     55
# 2         24     60
# 3         26     65
# 4         28     70
# 5         30     75
# 6         32     80
# 7         34     85
# 8         36     90
# 9         38     95
# 10        40    100

# %%
df.plot(kind="scatter", x="Diametro", y="Preco")
# Out:
# <Axes: xlabel='Diametro', ylabel='Preco'>

# %%
# Criando o modelo de regressão linear
from sklearn import linear_model

modelo = linear_model.LinearRegression()
# Selecionando as colunas para treinamento
x = df[["Diametro"]]
y = df[["Preco"]]
# Treinando o modelo
modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
# Printando a previsão
print(modelo.predict([[32]])[0][0])
# Out:
# 80.0
# C:\Users\Xavier\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
